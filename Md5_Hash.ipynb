# %%
import hashlib

# %%
inp_str = input("Enter a string: ")
# Out:
# Enter a string: Lorem ipsum dummy text

# %%
md5_obj = hashlib.md5(inp_str.encode('utf-8'))

# %%
print('Md5 hash of "' + inp_str + '" is: ' + str(md5_obj.hexdigest()))
# Out:
# Md5 hash of "Lorem ipsum dummy text" is: 804f3d5e9d95ab9f3ac2120d06c0822b
